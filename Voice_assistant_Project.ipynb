# %% [markdown]
# # Voice Assistant(David)
# ## Name: Avinash kumar chaurasia
# ## College: Madan Mohan Malviya University Of Technology Gorakhpur

# %%
import speech_recognition as sr
import pyttsx3
import datetime
import wikipedia
import webbrowser
import os
import time
import json
import requests
import pyjokes
import pywhatkit


engine=pyttsx3.init()
voices=engine.getProperty('voices')
engine.setProperty('voice',voices[0].id)
engine.setProperty('rate',190) 


#function to speak 
def speak(text):
    engine.say(text)
    engine.runAndWait()

    
#function to wish you at the time of david activation
def wishMe():
    hour=datetime.datetime.now().hour
    if hour>=0 and hour<12:
        speak("Good Morning")
        print("Good Morning")
    elif hour>=12 and hour<16:
        speak("Good Afternoon")
        print("Good Afternoon")
    else:
        speak("Good Evening")
        print("Good Evening")
        
        
        
#Function to take commmand from the user
def takeCommand():
    r=sr.Recognizer()
    with sr.Microphone() as source:
        print('Please Speak')
        r.pause_threshold=1 # pausing time
        print('listening')
        audio=r.listen(source)
        print('decoding')
        try:
            statement=r.recognize_google(audio,language='en-In')
            print(f"user said:{statement}\n")
        except Exception as e:
            speak("Sorry! unable to recognise, please say that again")
            return "None"
        return statement
    
    
    
#function to send sms on whats app
def send_sms():
                speak("Note! , you must be pre login to whats app. Are you logged in?")
                y = takeCommand()
                if "yes" in y or "Yes" in y:
                    speak("What is the contact number")
                    n = takeCommand()
                    if(n=="None"):
                        speak("Not able to recognise number")
                        print("Not able to recognise number")
                        send_sms()
                    n = n.replace(" ","")
                    print("Contact no. is : "+n)
                    speak("Contact no. is : "+n)
                    speak("Now,tell what to send")
                    t = takeCommand()
                    if(t=="None"):
                        speak("Not able to recognise message")
                        print("Not able to recognise message")
                        send_sms()
                    print("Message: "+t)
                    speak("Message is : "+t)
                    print("Please! verify the contact deatail and message... Is it okay to proceed?")
                    speak("Please! verify the contact deatail and message... Is it okay to proceed?")
                    print("Contact no: "+n)
                    print("Message: "+t)

                    l = takeCommand()
                    if "yes" in l or "Yes" in l:
                        print("Sending....")
                        speak("Sending....")
                        pywhatkit.sendwhatmsg_instantly("+91"+n, t)
                    else:
                        send_sms()
                        
                elif "exit" in y or "back" in y:
                    takeCommand()
                    
                    
                elif "no" in y or "No" in y:
                    speak("I am going back ,after logging in you can try again")
                        
                else:
                    speak("Say again")
                    send_sms()

                    
                    
                    
wishMe()
speak("This is your personal voice assistant David")
print('This is your personal voice assistant David')


if __name__=='__main__':


    while True:
        speak("Tell me how can I help you?")
        statement = takeCommand().lower()
        if statement==0:
            continue

        if 'is your name' in statement in statement:
            speak('My name is David and I was programmed to assist you.')
            
        elif "good bye" in statement or "ok bye" in statement or "stop" in statement:
            speak('your personal voice assistant David is shutting down,Good bye')
            print('your personal voice assistant David is shutting down,Good bye')
            break
        
    #Info belonging to david
        elif 'who are you' in statement or 'what can you do' in statement or'about yourself' in statement:
            speak('I am David, your personal voice assistant. I am programmed to assist you'
                  'You can ask me questions like what is your name?, who made you?, what can you do?')

    
        elif "who made you" in statement or "who created you" in statement or "who discovered you" in statement:
            print("I was developed by Avinash chaurasia")
            speak("I was developed by Avinash chaurasia")
            
    #Get the current time status
        elif 'current time' in statement or 'time' in statement:
            strTime=datetime.datetime.now().strftime("%H:%M:%S")
            speak(f"the time is {strTime}")
         
    #for getting information from wikipedia      
        elif 'wikipedia' in statement:
            speak('Searching Wikipedia...')
            statement =statement.replace("wikipedia ", "")
            results = wikipedia.summary(statement, sentences=3)
            speak("According to Wikipedia")
            print(results)
            speak(results)
     #Get a summary info of any person, by saying " who is rohit , who the heck is kohli"       
        elif 'who the heck ' in statement or 'who is ' in statement:
            person = statement.replace('who the heck ', '')
            info = wikipedia.summary(person, 1)
            print(info)
            speak(info)
            
    # Play a Video on YouTube or any music.... just say, "play moh moh ke dhage"
        elif 'play ' in statement:
            statement = statement.replace('play ','')
            pywhatkit.playonyt(statement)
            
    # by asking something funny or joke , david we will entertain you with jokes
        elif 'joke' in statement or 'something funny' in statement:
            speak(pyjokes.get_joke())
            
            
    # Send message on whatsapp, i have made a function to send sms at above
        elif 'send sms'in statement or 'sms'in statement:
            send_sms()
            
    
    # On below there is one function, that is used for searching , but depending on your default browser , it will
        #search on that deafault browser's search engine, but this is speacially for the google search engine
        elif 'search on google' in statement:
            speak("what you want to search")
            y=takeCommand()
            webbrowser.open_new("https://www.google.com/search?q="+y)
            time.sleep(5)
            
    # Know weather report by saying "weather, tell me weather, what is weather, current weather"
        elif "weather" in statement:
            api_key='5a25f792ab8acb09052068d9c2758903'
            base_url="https://api.openweathermap.org/data/2.5/weather?"
            speak("whats the city name")
            city_name=takeCommand()
            complete_url=base_url+"appid="+api_key+"&q="+city_name
            response = requests.get(complete_url)
            x=response.json()
            if x["cod"]!="404":
                y=x["main"]
                current_temperature = y["temp"]
                current_humidiy = y["humidity"]
                z = x["weather"]
                weather_description = z[0]["description"]
                speak(" Temperature in kelvin unit is " +
                      str(current_temperature) +
                      "\n humidity in percentage is " +
                      str(current_humidiy) +
                      "\n description  " +
                      str(weather_description))
                print(" Temperature in kelvin unit = " +
                      str(current_temperature) +
                      "\n humidity (in percentage) = " +
                      str(current_humidiy) +
                      "\n description = " +
                      str(weather_description))

            else:
                speak(" City Not Found ")
            
            
    # Search any webpage by saying "open facebook.com, open twitter.com open lenovo.com open pypi.org"
        elif "open " in statement:
            statement = statement.replace("open ", "")
            statement = statement.replace(" ", "")  #As there is no space in website URL, i am removing spaces
            webbrowser.open_new_tab("https://www."+statement)
            speak(statement+" is opening")
            
            
    #Say anything  like "show news" "latest news" "news". It will direct you to news page
        elif 'news' in statement or 'latest headline' in statement:
            news = webbrowser.open_new_tab("https://timesofindia.indiatimes.com/home/headlines")
            speak('Here are some headlines from the Times of India,Happy reading')
            time.sleep(6)

    #if user want to search any thing he have to only say like "search apple", it will direct you to new web page
        elif 'search'  in statement or 'tell me about' in statement:
            statement = statement.replace("search", "") or statement.replace("tell me about", "")
            webbrowser.open_new_tab(statement)
            time.sleep(5)
            
            
    #Here, i have given one more feature to not ask anything till schedued time
    #You can say,"wait for 10 second" "wait for "1 minute" "wait for 1 hour"
        elif 'wait' in statement or "sleep" in statement:
            print("Ok!....... ")
            speak("Ok! ")
            res=""
            if 'second' in statement:
                
                for m in statement:
                    if m.isdigit():
                        res=res+m
                statement = int(res)
                time.sleep(statement)
                
            elif 'minute' in statement:
                for m in statement:
                    if m.isdigit():
                        res=res+m
                statement = int(res)
                time.sleep(statement*60)
            
            elif 'hour' in statement:
                for m in statement:
                    if m.isdigit():
                        res=res+m
                statement = int(res)
                time.sleep(statement*3600)
                
            
            
            else:
                time.sleep(6)
        
                
            

            

time.sleep(3)
# Out:
# Good Evening
# This is your personal voice assistant David
# Please Speak
# listening
# decoding
# user said:who the heck is Rohit
#
# Rohit (Devanagri: रोहित), pronounced [ˈroːɦɪt̪]) is a given name, typically male, used among Indian people.
# Please Speak
# listening
# decoding
# user said:what is current time
#
# Please Speak
# listening
# decoding
# user said:search on Google
#
# Please Speak
# listening
# decoding
# user said:Rohit
#
# Please Speak
# listening
# decoding
# user said:stop
#
# your personal voice assistant David is shutting down,Good bye
